# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Intelligente Robotik
# #### WS 2024/25
# Julienne Eder, Lea Achter
#
# ---

# %%
# imports
from simulation import GridEnv
from algorithm import AStarAlgorithm
from metrics import Metrics

# %% [markdown]
# ### Erstellung der Grid Worlds

# %%
# ToDo: zeigen von verschiedenen Grids

# %%
# ToDo: Dynamische Griderstellung

# %% [markdown]
# ## Algorithmen

# %% [markdown]
# | | DRL mit CNN | A*  | Wavefront  | tbd |
# |:------------- |:------------- |:---------------:| -------------:| -------------:|
# | Ausführungszeit     | Cell         | Cell 3        | Cell 3        | Cell 3        |
# | Speicherkomplexität | Cell         | Cell 6        |Cell 3        | Cell 3        |
# | Laufzeitkomplexität | Cell         | Cell 9        |Cell 3        | Cell 3        |
# | Echtzeit (E) / Anytime (A)| Cell   | Cell 9        |Cell 3        | Cell 3        |
# | Zeit bis Konvergenz       | Cell   | Cell          |Cell 3        | Cell 3        |
# | Durchschnittliche Pfadlänge       | Cell   | Cell          |Cell 3        | Cell 3        |
#
#
#
# Deep Reinforcement Learning (DRL) \
# Convolutional Neural Network (CNN)

# %%
# ToDo: CProfile von jedem Algorithmus

# %%
# ToDo: aufzeigen von jedem Algorithmus + schöne Darstellung von dem Weg

# %%
# dummy Grid mit A*
metrics = Metrics()
path, size, df = metrics.get_metrics(algorithm='A-stern')

# %% [markdown]
# > RQ1: ....
