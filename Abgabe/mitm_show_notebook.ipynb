# %%
# %load_ext autoreload
# %autoreload 2

# %%
import json
import math
from collections import deque
from torch.nn.functional import grid_sample
from algorithm import MeetInTheMiddleAlgorithm
from simulation import CreateGrid

# %%
grid_creator = createGrid()
grid_dict = grid_creator.create_grid('detour_grid', 32)

# %%
start = (grid_dict['agent_x'], grid_dict['agent_y'])
goal = (grid_dict['goal_x'], grid_dict['goal_y'])
grid = grid_dict['grid']

# %%
alg = MeetInTheMiddleAlgorithm()
path, step = alg.find_path(start, goal, grid)
