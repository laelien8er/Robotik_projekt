# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import matplotlib.pyplot as plt
from algorithm import MeetInTheMiddleAlgorithm
from simulation import CreateGrid, GridWorldEnv
from helper import get_grid_img, get_grid, get_actions

# %%
# variables

benchmark = 'detour_grid'
size = 32

# %%
# dynamically create static Grid

grid_creator = CreateGrid()
grid_dict = grid_creator.create_grid(benchmark, size)

start = (grid_dict['agent_x'], grid_dict['agent_y'])
end = (grid_dict['goal_x'], grid_dict['goal_y'])
grid = grid_dict['grid']

# %%
# calculate path

alg = MeetInTheMiddleAlgorithm()
path, _ = alg.find_path(start, end, grid)

# %%
# print grid

data = get_grid_img(grid, start, end, path)

fig, ax = plt.subplots()
im = get_grid(data, ax=ax)
fig.tight_layout()
plt.axis('off')
plt.show()
