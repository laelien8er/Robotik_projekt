# %%
# %load_ext autoreload
# %autoreload 2

# %%
# imports
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from simulation import GridWorldEnv, CreateGrid
from algorithm import AStarAlgorithm
from helper import Metrics, get_grid, get_grid_img, create_show_grid

# %% [markdown]
# # Intelligente Robotik
# #### WS 2024/25
# Julienne Eder, Lea Achter
#
# ---

# %% [markdown]
# ## Dynamische Erstellung der Grid Worlds

# %%
# ToDo: zeigen von verschiedenen Grids

start, end, grid = dummy_grid_generation(benchmark='show')
data = get_grid_img(grid, start, end)

fig, ax = plt.subplots()
im = get_grid(data, ax=ax)
fig.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 3
#       1 # ToDo: zeigen von verschiedenen Grids
# ----> 3 start, end, grid = dummy_grid_generation(benchmark='show')
#       4 data = get_grid_img(grid, start, end)
#       6 fig, ax = plt.subplots()
#
# NameError: name 'dummy_grid_generation' is not defined

# %%
# ToDo: Dynamische Griderstellung

# %% [markdown]
# ## Algorithmen

# %% [markdown]
# | |  A*  | Wavefront  | MITM | Q-Learning| SASAR|
# |:------------- |:------------- |:---------------:| -------------:| -------------:|-------------:|
# | Ausführungszeit     | Cell         | Cell 3        | Cell 3        | Cell 3        |  Cell 3        |
# | Speicherkomplexität | Cell         | Cell 6        |Cell 3        | Cell 3        |  Cell 3        |
# | Laufzeitkomplexität | Cell         | Cell 9        |Cell 3        | Cell 3        | Cell 3        |
# | Echtzeit (E) / Anytime (A)| Cell   | Cell 9        |Cell 3        | Cell 3        | Cell 3        |
# | Zeit bis Konvergenz       | Cell   | Cell          |Cell 3        | Cell 3        | Cell 3        |
# | Durchschnittliche Pfadlänge       | Cell   | Cell          |Cell 3        | Cell 3        | Cell 3        |
#
#
#
# Meet-in-the-middle (MITM)

# %% [markdown]
# ### A* Algorithmus

# %% [markdown]
# ToDo: Beschreibung

# %%
# example 

data = create_show_grid(algorithm='A-star')
fig, ax = plt.subplots()
im = get_grid(data, ax=ax)
fig.tight_layout()
plt.axis('off')
plt.show()

# %%
# get metrics 
size_grid = 32
num_runns = 5

metrics = Metrics()
df = metrics.get_metrics(algorithm='A-star', size_grid=size_grid, num_runns=num_runns)

print(f"\n\nMetriken für den A*-Algorithmus mit einer Gridgröße von {size_grid} und {num_runns} zufälligen Initializierungen des Grids\n")
df
# Out:
# Metriken für den A*-Algorithmus mit einer Gridgröße von 32 und 5 zufälligen Initializierungen des Grids
#          benchmark     avg_time (sec)      avg_path_length  \
# 0            empty  0.00624 ± 0.00365   34.60000 ± 2.05913
# 1        star_grid  0.05061 ± 0.00535   57.80000 ± 2.92575
# 2      simple_grid  0.00597 ± 0.00339   38.20000 ± 3.24962
# 3  bottleneck_grid  0.00333 ± 0.00148   39.20000 ± 2.92575
# 4        trap_grid  0.00555 ± 0.00278   45.80000 ± 3.65513
# 5  doubletrap_grid  0.00330 ± 0.00142   40.00000 ± 4.28952
# 6      detour_grid  0.00920 ± 0.00102   73.40000 ± 2.05913
# 7              all  0.01203 ± 0.01615  47.00000 ± 13.22336
#
#      avg_steps_to_converge
# 0    700.00000 ± 309.58488
# 1  3331.60000 ± 1038.27657
# 2   5539.00000 ± 259.30368
# 3   6431.00000 ± 208.43416
# 4   7392.20000 ± 328.94826
# 5   8338.00000 ± 211.99717
# 6   9625.20000 ± 452.12671
# 7  5908.14286 ± 2871.98858

# %% [markdown]
# ### Wavefront

# %% [markdown]
# > RQ1: ....
